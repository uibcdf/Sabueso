# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # get nucleotide binding regions

# %%
#from sabueso.tools.string_uniprot import to_uniprotkb_XMLDict
#from sabueso.tools.uniprotkb_XMLDict import get_dna_binding_regions

# %%
#item = to_uniprotkb_XMLDict('uniprot:P46200')

# %%
#dna_binding_regions = get_dna_binding_regions(item)

# %%
#dna_binding_regions
# Out:
# [{'references': [<UniProtKB: P46200>, <PROSITE-ProRule: PRU00625>],
#   'description': 'H-T-H motif',
#   'begin': '63',
#   'end': '86'},
#  {'references': [<UniProtKB: P46200>, <PROSITE-ProRule: PRU00625>],
#   'description': 'H-T-H motif',
#   'begin': '115',
#   'end': '138'},
#  {'references': [<UniProtKB: P46200>, <PROSITE-ProRule: PRU00625>],
#   'description': 'H-T-H motif',
#   'begin': '166',
#   'end': '189'}]

# %%
#dna_binding_regions = get_dna_binding_regions(item, as_cards=True)

# %%
#dna_binding_regions
# Out:
# [<DNABindingRegionCard: H-T-H motif 63-86>,
#  <DNABindingRegionCard: H-T-H motif 115-138>,
#  <DNABindingRegionCard: H-T-H motif 166-189>]

# %%
#dna_binding_regions[0].to_pandas_DataFrame().T
# Out:
#                                                       63-86
# references   [UniProtKB: P46200, PROSITE-ProRule: PRU00625]
# description                                     H-T-H motif
# begin                                                    63
# end                                                      86
