# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # get regions

# %%
#from sabueso.tools.string_uniprot import to_uniprotkb_XMLDict
#from sabueso.tools.uniprotkb_XMLDict import get_regions

# %%
#item = to_uniprotkb_XMLDict('uniprot:P19367')
#item = to_uniprotkb_XMLDict('uniprot:P52789')
#item = to_uniprotkb_XMLDict('uniprot:P52790')
#item = to_uniprotkb_XMLDict('uniprot:P35557')

# %%
#regions = get_regions(item)

# %%
#regions
# Out:
# [{'references': [<UniProtKB: P19367>, <PubMed: 1985912>],
#   'description': 'Mitochondrial-binding peptide (MBP)',
#   'begin': '1',
#   'end': '10'},
#  {'references': [<UniProtKB: P19367>, <PROSITE-ProRule: PRU01084>],
#   'description': 'Hexokinase small subdomain 1',
#   'begin': '73',
#   'end': '207'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1CZA>,
#    <PDB: 1HKB>,
#    <PDB: 1QHA>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>],
#   'description': 'Glucose-6-phosphate 1 binding',
#   'begin': '84',
#   'end': '91'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PubMed: 9735292>,
#    <PDB: 1CZA>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 1HKC>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 1 binding',
#   'begin': '172',
#   'end': '173'},
#  {'references': [<UniProtKB: P19367>, <PROSITE-ProRule: PRU01084>],
#   'description': 'Hexokinase large subdomain 1',
#   'begin': '208',
#   'end': '447'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PubMed: 9735292>,
#    <PDB: 1CZA>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 1HKC>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 1 binding',
#   'begin': '208',
#   'end': '209'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PubMed: 9735292>,
#    <PDB: 1CZA>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 1HKC>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 1 binding',
#   'begin': '291',
#   'end': '294'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1CZA>,
#    <PDB: 1HKB>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Glucose-6-phosphate 1 binding',
#   'begin': '413',
#   'end': '415'},
#  {'references': [<UniProtKB: P19367>, <PROSITE-ProRule: PRU01084>],
#   'description': 'Hexokinase small subdomain 2',
#   'begin': '521',
#   'end': '655'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PDB: 1CZA>,
#    <PDB: 1QHA>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>],
#   'description': 'Glucose-6-phosphate 2 binding',
#   'begin': '532',
#   'end': '536'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 2 binding',
#   'begin': '603',
#   'end': '604'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1CZA>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 2 binding',
#   'begin': '620',
#   'end': '621'},
#  {'references': [<UniProtKB: P19367>, <PROSITE-ProRule: PRU01084>],
#   'description': 'Hexokinase large subdomain 2',
#   'begin': '656',
#   'end': '895'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1CZA>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 2 binding',
#   'begin': '656',
#   'end': '657'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1CZA>,
#    <PDB: 1DGK>,
#    <PDB: 1HKB>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Substrate 2 binding',
#   'begin': '682',
#   'end': '683'},
#  {'references': [<UniProtKB: P19367>,
#    <PubMed: 10574795>,
#    <PubMed: 10686099>,
#    <PubMed: 9493266>,
#    <PDB: 1CZA>,
#    <PDB: 1HKB>,
#    <PDB: 1QHA>,
#    <PDB: 4F9O>,
#    <PDB: 4FOE>,
#    <PDB: 4FOI>,
#    <PDB: 4FPA>,
#    <PDB: 4FPB>],
#   'description': 'Glucose-6-phosphate 2 binding',
#   'begin': '861',
#   'end': '863'}]

# %%
#regions = get_regions(item, as_cards=True)

# %%
#regions
# Out:
# [<RegionCard: Mitochondrial-binding peptide (MBP) 1-10>,
#  <RegionCard: Hexokinase small subdomain 1 73-207>,
#  <RegionCard: Glucose-6-phosphate 1 binding 84-91>,
#  <RegionCard: Substrate 1 binding 172-173>,
#  <RegionCard: Hexokinase large subdomain 1 208-447>,
#  <RegionCard: Substrate 1 binding 208-209>,
#  <RegionCard: Substrate 1 binding 291-294>,
#  <RegionCard: Glucose-6-phosphate 1 binding 413-415>,
#  <RegionCard: Hexokinase small subdomain 2 521-655>,
#  <RegionCard: Glucose-6-phosphate 2 binding 532-536>,
#  <RegionCard: Substrate 2 binding 603-604>,
#  <RegionCard: Substrate 2 binding 620-621>,
#  <RegionCard: Hexokinase large subdomain 2 656-895>,
#  <RegionCard: Substrate 2 binding 656-657>,
#  <RegionCard: Substrate 2 binding 682-683>,
#  <RegionCard: Glucose-6-phosphate 2 binding 861-863>]

# %%
#regions[0].to_pandas_DataFrame().T
# Out:
#                                              1-10
# references   [UniProtKB: P19367, PubMed: 1985912]
# description   Mitochondrial-binding peptide (MBP)
# begin                                           1
# end                                            10
