# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # get secondary structure

# %%
#from sabueso.tools.string_uniprot import to_uniprotkb_XMLDict
#from sabueso.tools.uniprotkb_XMLDict import get_secondary_structure

# %%
#item = to_uniprotkb_XMLDict('uniprot:P19367')
#item = to_uniprotkb_XMLDict('uniprot:P46200')
#item = to_uniprotkb_XMLDict('uniprot:P55197')
#item = to_uniprotkb_XMLDict('uniprot:P05937')
#item = to_uniprotkb_XMLDict('uniprot:P00374')
#item = to_uniprotkb_XMLDict('uniprot:Q9FFX4')
#item = to_uniprotkb_XMLDict('uniprot:P62166')

# %%
#secondary_structure = get_secondary_structure(item)

# %%
#secondary_structure['turns']
# Out:
# [{'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '53',
#   'end': '55'},
#  {'references': [<UniProtKB: P19367>, <PDB: 4FPB>],
#   'description': None,
#   'begin': '179',
#   'end': '182'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '264',
#   'end': '273'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '326',
#   'end': '329'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '345',
#   'end': '347'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '690',
#   'end': '692'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '712',
#   'end': '715'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '717',
#   'end': '721'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '734',
#   'end': '737'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '747',
#   'end': '749'},
#  {'references': [<UniProtKB: P19367>, <PDB: 1CZA>],
#   'description': None,
#   'begin': '774',
#   'end': '777'}]

# %%
#secondary_structure = get_secondary_structure(item, as_cards=True)

# %%
#secondary_structure
# Out:
# <SecondaryStructureCard: 37 helices, 24 strands and 11 turns>

# %%
#secondary_structure.to_pandas_DataFrame().T
# Out:
#                                                             ss
# references                                 [UniProtKB: P19367]
# description                                               None
# helices      [<HelixCard: None 17-25>, <HelixCard: None 27-...
# strands      [<StrandCard: None 78-100>, <StrandCard: None ...
# turns        [<TurnCard: None 53-55>, <TurnCard: None 179-1...
