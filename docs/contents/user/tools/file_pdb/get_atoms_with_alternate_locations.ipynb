# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Get atoms with alternate locations

# %%
from sabueso.tools import file_pdb

# %%
file_pdb.download('1brs')
# Out:
# '1brs.pdb'

# %%
aa = file_pdb.get_atoms_with_alternate_locations('1brs.pdb')

# %%
aa
# Out:
# {1: ['CB-2690/SER-14/D',
#   'CB-2691/SER-14/D',
#   'OG-2692/SER-14/D',
#   'OG-2693/SER-14/D']}
