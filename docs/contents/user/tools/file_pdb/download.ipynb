# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Download

# %%
from sabueso.tools.file_pdb import download

# %%
download('1brs')
# Out:
# '1brs.pdb'

# %%
from os import remove

# %%
remove('1brs.pdb')
