# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # download

# %%
from sabueso.tools.database_UniProtKB import download

# %%
download(data='reviewed', format='xml', check_size=True)
# Out:
# 757.5148849487305

# %%
download(data='isoform sequences', format='fasta', check_size=True)
# Out:
# 8.00516128540039

# %%
download(data='isoform sequences', format='fasta')
# Out:
# uniprot_sprot_varsplic.fasta.gz downloaded as ./uniprot_sprot_varsplic.fasta.gz in 0:00:06.587334

# %% [markdown]
# https://www.uniprot.org/help/retrieve_sets
# https://www.uniprot.org/downloads
# https://ftp.uniprot.org/pub/databases/uniprot/
