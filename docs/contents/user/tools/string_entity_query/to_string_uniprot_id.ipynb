# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # to string uniprot id

# %%
#from sabueso.tools.string_entity_query import to_string_uniprot_id

# %%
#to_string_uniprot_id('hexokinase-1 human')
# Out:
# ['P19367',
#  'Q59RW5',
#  'P52789',
#  'P52790',
#  'Q2TB90',
#  'P35557',
#  'G1PCR5',
#  'F1RC38',
#  'B8A4K2']

# %%
#to_string_uniprot_id('name:hexokinase-1 organism:human')
# Out:
# 'P19367'

# %%
#to_string_uniprot_id('morphine')
# Out:
# ['P31044',
#  'P40227',
#  'P42866',
#  'P33535',
#  'P35372',
#  'P63318',
#  'Q8R5J9',
#  'Q071N0',
#  'O15130',
#  'P32300',
#  'P41143',
#  'P10829',
#  'Q9WVA9',
#  'P63319',
#  'Q4R4U2',
#  'P05129',
#  'P05128',
#  'Q5IS39',
#  'P97266',
#  'P41145',
#  'A4UHT7',
#  'Q9MYW9',
#  'A0A087X1C5',
#  'G1LHT5',
#  'G3R8H1',
#  'A0A2I2YKG4',
#  'G3QDE4',
#  'G3QL46',
#  'A0A452U3X3',
#  'A0A452RU72',
#  'A0A2K5JE10',
#  'A0A2K5K4J4',
#  'F7FEQ3',
#  'F7FY04',
#  'A0A024R7V4',
#  'A0A0K0K1K3',
#  'A0A0R4J0N8',
#  'A0A0G2KA64',
#  'D4A0Y9',
#  'A9YZQ5',
#  'U3JBW5',
#  'U3KES8',
#  'F7A1R2',
#  'A0A2Y9N8M4',
#  'G1T1Q0',
#  'A0A2K6MYH2',
#  'F1PMX4',
#  'A0A2I2ZTJ4',
#  'G7PM48',
#  'A0A2K5VFP3',
#  'A0A2K5TSZ5',
#  'A0A2K6JQA9',
#  'G1P8G3',
#  'G1PK18',
#  'A0A452UUJ9',
#  'G1T644',
#  'A0A2K5CXD8',
#  'F6T507',
#  'A0A096P1M8',
#  'A0A2K5WL67',
#  'A0A087X0H5',
#  'Q9GZT4',
#  'Q04206',
#  'P35503',
#  'O75915',
#  'P22005',
#  'P49799',
#  'Q76EQ0',
#  'Q9QZX7',
#  'P37108',
# ...

# %%
#to_string_uniprot_id('mu opioid receptor')
