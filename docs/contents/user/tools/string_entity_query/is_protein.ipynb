# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # is protein

# %%
#from sabueso.tools.string_entity_query import is_protein

# %%
#is_protein('name:hexokinase-1 organism:human')
# Out:
# True
