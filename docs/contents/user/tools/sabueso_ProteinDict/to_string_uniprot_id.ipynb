# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # to_string_uniprot_id

# %%
#from sabueso.tools.sabueso_ProteinDict import to_string_uniprot_id
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1305756/3685162531.py in <module>
# ----> 1 from sabueso.tools.sabueso_ProteinDict import to_string_uniprot_id
#
# ImportError: cannot import name 'to_string_uniprot_id' from 'sabueso.tools.sabueso_ProteinDict' (/home/diego/projects-uibcdf/sabueso/sabueso/tools/sabueso_ProteinDict/__init__.py)

# %%
#item = {'name':'hexokinase 1', 'organism':'human'}

# %%
#to_string_uniprot_id(item)
# Out:
# 'P19367'
