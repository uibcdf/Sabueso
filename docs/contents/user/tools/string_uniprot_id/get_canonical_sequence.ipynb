# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # get isoforms

# %%
#from sabueso.tools.string_uniprot import get_canonical_sequence

# %%
#item = 'uniprot:P19367'
#item = 'uniprot:P52789'
#item = 'uniprot:P52790'
#item = 'uniprot:P35557'

# %%
#sequence = get_canonical_sequence(item)

# %%
#sequence
