# %% [markdown]
# # string is uniprot

# %%
from sabueso.tools.string_uniprot_id import is_string_uniprot_id

# %%
is_string_uniprot_id('A2BC19')
# Out:
# True

# %%
is_string_uniprot_id('P12345')
# Out:
# True

# %%
is_string_uniprot_id('P12345-2')
# Out:
# False

# %%
is_string_uniprot_id('A0A023GPI8')
# Out:
# True

# %%
is_string_uniprot_id('1BRS')
# Out:
# False

# %% [markdown]
# Regex according to https://www.uniprot.org/help/accession_numbers:
#
# [OPQ][0-9][A-Z0-9]{3}[0-9]|[A-NR-Z][0-9]([A-Z][A-Z0-9]{2}[0-9]){1,2}
