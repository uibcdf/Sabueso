# %%
from sabueso.database import UniProtKB

# %%
#xml_file = uniprotkb.uniprot_id.to_xml_file('P19367', 'P19367.xml')

# %%
xml_dict = UniProtKB.xml_file.to_xml_dict('P19367.xml')

# %%
xml_dict['uniprot']['entry'].keys()
# Out:
# dict_keys(['@dataset', '@created', '@modified', '@version', '@xmlns', 'accession', 'name', 'protein', 'gene', 'organism', 'reference', 'comment', 'dbReference', 'proteinExistence', 'keyword', 'feature', 'evidence', 'sequence'])

# %% [markdown]
# Falta reference, comment, proteinExistence, keyword

# %%
xml_dict['uniprot']['entry']['reference']
# Out:
# [{'@key': '1',
#   'citation': {'@type': 'journal article',
#    '@date': '1988',
#    '@name': 'Biochem. Biophys. Res. Commun.',
#    '@volume': '157',
#    '@first': '937',
#    '@last': '943',
#    'title': 'Human hexokinase: sequences of amino- and carboxyl-terminal halves are homologous.',
#    'authorList': {'person': [{'@name': 'Nishi S.'},
#      {'@name': 'Seino S.'},
#      {'@name': 'Bell G.I.'}]},
#    'dbReference': [{'@type': 'PubMed', '@id': '3207429'},
#     {'@type': 'DOI', '@id': '10.1016/s0006-291x(88)80964-1'}]},
#   'scope': ['NUCLEOTIDE SEQUENCE [MRNA] (ISOFORM 1)', 'VARIANT MET-776']},
#  {'@key': '2',
#   'citation': {'@type': 'journal article',
#    '@date': '1998',
#    '@name': 'Biochem. J.',
#    '@volume': '331',
#    '@first': '607',
#    '@last': '613',
#    'title': "Structure of the human hexokinase type I gene and nucleotide sequence of the 5' flanking region.",
#    'authorList': {'person': [{'@name': 'Ruzzo A.'},
#      {'@name': 'Andreoni F.'},
# ...
