# %%
from sabueso.database import UniProtKB

# %%
item = 'uniprot:P19367'
#item = 'uniprot:P52789'
#item = 'uniprot:P52790'
#item = 'uniprot:P35557'

#item = 'uniprot:P0DOK3'

# %%
#xml_file = uniprotkb.uniprot_id.to_xml_file('P19367', 'P19367.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('P52789', 'P52789.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('P52790', 'P52790.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('P35557', 'P35557.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('P0DOK3', 'P0DOK3.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('P13574', 'P13574.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('P41972', 'P41972.xml')
#xml_file = UniProtKB.uniprot_id.to_xml_file('O95696', 'O95696.xml')

# %%
#xml_dict = UniProtKB.xml_file.to_xml_dict('P19367.xml')
#xml_dict = UniProtKB.xml_file.to_xml_dict('P52789.xml')
#xml_dict = UniProtKB.xml_file.to_xml_dict('P03211.xml')
xml_dict = UniProtKB.xml_file.to_xml_dict('P19367.xml')

# %%
xml_dict['uniprot']['entry']['comment']
# Out:
# [{'@type': 'function',
#   'text': {'@evidence': '1 8 13 14',
#    '#text': 'Catalyzes the phosphorylation of various hexoses, such as D-glucose, D-glucosamine, D-fructose, D-mannose and 2-deoxy-D-glucose, to hexose 6-phosphate (D-glucose 6-phosphate, D-glucosamine 6-phosphate, D-fructose 6-phosphate, D-mannose 6-phosphate and 2-deoxy-D-glucose 6-phosphate, respectively) (PubMed:1637300, PubMed:25316723, PubMed:27374331). Does not phosphorylate N-acetyl-D-glucosamine (PubMed:27374331). Mediates the initial step of glycolysis by catalyzing phosphorylation of D-glucose to D-glucose 6-phosphate (By similarity). Involved in innate immunity and inflammation by acting as a pattern recognition receptor for bacterial peptidoglycan (PubMed:27374331). When released in the cytosol, N-acetyl-D-glucosamine component of bacterial peptidoglycan inhibits the hexokinase activity of HK1 and causes its dissociation from mitochondrial outer membrane, thereby activating the NLRP3 inflammasome (PubMed:27374331).'}},
#  {'@type': 'catalytic activity',
#   'reaction': {'@evidence': '8 14',
#    'text': 'ATP + D-hexose = ADP + D-hexose 6-phosphate + H(+)',
#    'dbReference': [{'@type': 'Rhea', '@id': 'RHEA:22740'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:4194'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:15378'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:30616'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:61567'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:456216'},
#     {'@type': 'EC', '@id': '2.7.1.1'}]},
#   'physiologicalReaction': {'@direction': 'left-to-right',
#    '@evidence': '8 14',
#    'dbReference': {'@type': 'Rhea', '@id': 'RHEA:22741'}}},
#  {'@type': 'catalytic activity',
#   'reaction': {'@evidence': '1',
#    'text': 'ATP + D-fructose = ADP + D-fructose 6-phosphate + H(+)',
#    'dbReference': [{'@type': 'Rhea', '@id': 'RHEA:16125'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:15378'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:30616'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:37721'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:61527'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:456216'},
#     {'@type': 'EC', '@id': '2.7.1.1'}]},
#   'physiologicalReaction': {'@direction': 'left-to-right',
#    '@evidence': '1',
#    'dbReference': {'@type': 'Rhea', '@id': 'RHEA:16126'}}},
#  {'@type': 'catalytic activity',
#   'reaction': {'@evidence': '1',
#    'text': 'ATP + D-glucose = ADP + D-glucose 6-phosphate + H(+)',
#    'dbReference': [{'@type': 'Rhea', '@id': 'RHEA:17825'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:4167'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:15378'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:30616'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:61548'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:456216'},
#     {'@type': 'EC', '@id': '2.7.1.1'}]},
#   'physiologicalReaction': {'@direction': 'left-to-right',
#    '@evidence': '1',
#    'dbReference': {'@type': 'Rhea', '@id': 'RHEA:17826'}}},
#  {'@type': 'catalytic activity',
#   'reaction': {'@evidence': '1',
#    'text': 'ATP + D-mannose = ADP + D-mannose 6-phosphate + H(+)',
#    'dbReference': [{'@type': 'Rhea', '@id': 'RHEA:11028'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:4208'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:15378'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:30616'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:58735'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:456216'},
#     {'@type': 'EC', '@id': '2.7.1.1'}]},
#   'physiologicalReaction': {'@direction': 'left-to-right',
#    '@evidence': '1',
#    'dbReference': {'@type': 'Rhea', '@id': 'RHEA:11029'}}},
#  {'@type': 'catalytic activity',
#   'reaction': {'@evidence': '14',
#    'text': 'ATP + D-glucosamine = ADP + D-glucosamine 6-phosphate + H(+)',
#    'dbReference': [{'@type': 'Rhea', '@id': 'RHEA:10948'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:15378'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:30616'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:58723'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:58725'},
#     {'@type': 'ChEBI', '@id': 'CHEBI:456216'},
#     {'@type': 'EC', '@id': '2.7.1.1'}]},
#   'physiologicalReaction': {'@direction': 'left-to-right',
#    '@evidence': '14',
#    'dbReference': {'@type': 'Rhea', '@id': 'RHEA:10949'}}},
#  {'@type': 'activity regulation',
#   'text': {'@evidence': '8 14',
#    '#text': 'Hexokinase is an allosteric enzyme inhibited by its product D-glucose 6-phosphate (PubMed:1637300). Hexokinase activity is inhibited by N-acetyl-D-glucosamine (PubMed:27374331).'}},
#  {'@type': 'pathway',
#   'text': {'@evidence': '26 28',
#    '#text': 'Carbohydrate metabolism; hexose metabolism.'}},
#  {'@type': 'pathway',
#   'text': {'@evidence': '1',
#    '#text': 'Carbohydrate degradation; glycolysis; D-glyceraldehyde 3-phosphate and glycerone phosphate from D-glucose: step 1/4.'}},
#  {'@type': 'subunit',
#   'text': {'@evidence': '2 5 11',
#    '#text': 'Monomer (PubMed:10686099). Interacts with RABL2/RABL2A; binds preferentially to GTP-bound RABL2 (By similarity). Interacts with VDAC1 (PubMed:22304920). The HK1-VDAC1 complex interacts with ATF2 (PubMed:22304920). Interacts (via N-terminal spermatogenic cell-specific region) with PFKM (via C-terminus) (By similarity).'}},
#  {'@type': 'interaction',
#   'interactant': [{'@intactId': 'EBI-713162', 'id': 'P19367'},
#    {'@intactId': 'EBI-621482', 'id': 'P12931', 'label': 'SRC'}],
#   'organismsDiffer': 'false',
#   'experiments': '2'},
#  {'@type': 'interaction',
#   'interactant': [{'@intactId': 'EBI-713162', 'id': 'P19367'},
#    {'@intactId': 'EBI-354158', 'id': 'P21796', 'label': 'VDAC1'}],
#   'organismsDiffer': 'false',
#   'experiments': '2'},
#  {'@type': 'interaction',
#   'interactant': [{'@intactId': 'EBI-713162', 'id': 'P19367'},
#    {'@intactId': 'EBI-298680', 'id': 'P05480', 'label': 'Src'}],
#   'organismsDiffer': 'true',
#   'experiments': '8'},
#  {'@type': 'subcellular location',
#   'subcellularLocation': [{'location': {'@evidence': '10 14',
#      '#text': 'Mitochondrion outer membrane'},
#     'topology': {'@evidence': '25', '#text': 'Peripheral membrane protein'}},
#    {'location': [{'@evidence': '14', '#text': 'Cytoplasm'},
#      {'@evidence': '14', '#text': 'Cytosol'}]}],
#   'text': {'@evidence': '14 27',
#    '#text': 'The mitochondrial-binding peptide (MBP) region promotes association with the mitochondrial outer membrane (Probable). Dissociates from the mitochondrial outer membrane following inhibition by N-acetyl-D-glucosamine, leading to relocation to the cytosol (PubMed:27374331).'}},
#  {'@type': 'alternative products',
#   'event': {'@type': 'alternative splicing'},
#   'isoform': [{'id': 'P19367-1',
#     'name': ['1', 'Common'],
#     'sequence': {'@type': 'displayed'}},
#    {'id': 'P19367-2',
#     'name': ['2', 'Erythrocyte', 'R'],
#     'sequence': {'@type': 'described', '@ref': 'VSP_002071'}},
#    {'id': 'P19367-3',
#     'name': ['3', 'TA', 'TB'],
#     'sequence': {'@type': 'described', '@ref': 'VSP_002072'}},
#    {'id': 'P19367-4',
#     'name': ['4', 'TD'],
#     'sequence': {'@type': 'described', '@ref': 'VSP_002073'}}]},
#  {'@type': 'tissue specificity',
#   'text': {'@evidence': '6 20',
#    '#text': 'Isoform 2: Erythrocyte specific (Ref.6). Isoform 3: Testis-specific (PubMed:10978502). Isoform 4: Testis-specific (PubMed:10978502).'}},
#  {'@type': 'domain',
#   'text': {'@evidence': '4 18 19',
#    '#text': 'The N- and C-terminal halves of this hexokinase contain a hexokinase domain (PubMed:9493266, PubMed:9735292, PubMed:10574795). The catalytic activity is associated with the C-terminus while regulatory function is associated with the N-terminus (PubMed:9493266, PubMed:9735292, PubMed:10574795). Each domain can bind a single D-glucose and D-glucose 6-phosphate molecule (PubMed:9493266).'}},
#  {'@type': 'disease',
#   '@evidence': '7 17',
#   'disease': {'@id': 'DI-01739',
#    'name': 'Hexokinase deficiency',
#    'acronym': 'HK deficiency',
#    'description': 'Rare autosomal recessive disease with nonspherocytic hemolytic anemia as the predominant clinical feature.',
#    'dbReference': {'@type': 'MIM', '@id': '235700'}},
#   'text': 'The disease is caused by variants affecting the gene represented in this entry.'},
#  {'@type': 'disease',
#   '@evidence': '9',
#   'disease': {'@id': 'DI-03795',
#    'name': 'Neuropathy, hereditary motor and sensory, Russe type',
#    'acronym': 'HMSNR',
#    'description': 'An autosomal recessive progressive complex peripheral neuropathy characterized by onset in the first decade of distal lower limb weakness and muscle atrophy resulting in walking difficulties. Distal impairment of the upper limbs usually occurs later, as does proximal lower limb weakness. There is distal sensory impairment, with pes cavus and areflexia. Laboratory studies suggest that it is a myelinopathy resulting in reduced nerve conduction velocities in the demyelinating range as well as a length-dependent axonopathy.',
#    'dbReference': {'@type': 'MIM', '@id': '605285'}},
#   'text': 'The disease is caused by variants affecting the gene represented in this entry.'},
#  {'@type': 'disease',
#   '@evidence': '12 13',
#   'disease': {'@id': 'DI-04983',
#    'name': 'Retinitis pigmentosa 79',
#    'acronym': 'RP79',
#    'description': 'A form of retinitis pigmentosa, a retinal dystrophy belonging to the group of pigmentary retinopathies. Retinitis pigmentosa is characterized by retinal pigment deposits visible on fundus examination and primary loss of rod photoreceptor cells followed by secondary loss of cone photoreceptors. Patients typically have night vision blindness and loss of midperipheral visual field. As their condition progresses, they lose their far peripheral visual field and eventually central vision as well. RP79 inheritance is autosomal dominant.',
#    'dbReference': {'@type': 'MIM', '@id': '617460'}},
#   'text': 'The disease is caused by variants affecting the gene represented in this entry.'},
#  {'@type': 'disease',
#   '@evidence': '15',
#   'disease': {'@id': 'DI-05639',
#    'name': 'Neurodevelopmental disorder with visual defects and brain anomalies',
#    'acronym': 'NEDVIBA',
#    'description': 'A disorder characterized by global developmental delay, speech delay, intellectual disability, structural brain abnormalities, and visual impairments including retinitis pigmentosa and optic atrophy.',
#    'dbReference': {'@type': 'MIM', '@id': '618547'}},
#   'text': 'The disease is caused by variants affecting the gene represented in this entry.'},
#  {'@type': 'similarity',
#   'text': {'@evidence': '3 25', '#text': 'Belongs to the hexokinase family.'}},
#  {'@type': 'caution',
#   'text': {'@evidence': '4 5 18',
#    '#text': 'Hexokinase is known to act as a monomer (PubMed:10686099). It however homodimerizes at elevated protein concentrations used for crystallizations (PubMed:9493266, PubMed:10574795).'}},
#  {'@type': 'online information',
#   '@name': 'Wikipedia',
#   'link': {'@uri': 'https://en.wikipedia.org/wiki/Hexokinase'},
#   'text': 'Hexokinase entry'}]

# %%
for feature in xml_dict['uniprot']['entry']['comment']:
    if feature['@type'].startswith('DNA-binding'):
        print(True)

# %%
xml_dict['uniprot']['entry']['feature']
